# %% [markdown]
# # Ejecutar el Miner

# %% [markdown]
# Primero importamos `miner.py` moviendo el systema para que encuentre el modulo miner.py

# %%
import sys
sys.path.append("../miner")
import miner

# %% [markdown]
# Luego generamos la lista de los repositorios, filtrando por los que hayan tenido actividad en menos de un mes y con un limite de 50 repositorios para evitar un analisis de un tiempo excesivo para efectos de este proyecto, dentro del miner el limite puede ser modificado según la necesidad al igual que la organizacion a analizar, en este caso `PerfectHQ`

# %%
lista = miner.obtener_repos()
# Out:
# Obteniendo repositorios activos de PrefectHQ...
# Se encontraron 17 repositorios activos.

# %% [markdown]
# Finalmente realizamos SBOMs de las librerias utilizadas con Syft y luego busca vulnerabilidades con Grype, las almacenamos en archvios `.json` para procesarlos más adelante

# %%
for repo in lista:
    miner.ejecutar_herramientas(repo)
print("\nProceso finalizado.")
# Out:
# Analizando: prefect
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: prefect-helm
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: prefab
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: fastmcp
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: colin
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: prefect-mcp-server
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: prefect-fastmcp-demos
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: marvin
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: prefect-cloud
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: prefect-operator
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: dev-log
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: prometheus-prefect-exporter
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: prefect-design
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: qa-wolf-flows
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: terraform-prefect-bucket-sensor
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: terraform-provider-prefect
#    Generando SBOM...
#    Buscando vulnerabilidades...
# Analizando: actions-updatecli-apply
#    Generando SBOM...
#    Buscando vulnerabilidades...
#
# Proceso finalizado.
